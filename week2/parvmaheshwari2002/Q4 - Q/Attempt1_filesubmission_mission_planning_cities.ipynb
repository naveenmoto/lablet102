# %% [markdown]
# ## Shortest path planning
#
# example from motion planning course offered by Univ of Toronto
#
# A map of Berkley, California is given
# * Implement Dijkstra's search algorithm on a road network graph.
# * Implement the A* search algorithm using a Euclidean heuristic on a road network graph.

# %% [markdown]
# [OSMNX library](https://osmnx.readthedocs.io/en/stable/) is used to generate Python graphs from Open Street Map (OSM) data.

# %%
# !pip install osmnx
# Out:
# Requirement already satisfied: osmnx in /usr/local/lib/python3.7/dist-packages (1.1.1)
# Requirement already satisfied: geopandas>=0.9 in /usr/local/lib/python3.7/dist-packages (from osmnx) (0.9.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.19.5)
# Requirement already satisfied: Shapely>=1.7 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.7.1)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.7/dist-packages (from osmnx) (2.25.1)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.1.5)
# Requirement already satisfied: pyproj>=2.6 in /usr/local/lib/python3.7/dist-packages (from osmnx) (3.1.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.7/dist-packages (from osmnx) (3.4.2)
# Requirement already satisfied: Rtree>=0.9 in /usr/local/lib/python3.7/dist-packages (from osmnx) (0.9.7)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.7/dist-packages (from osmnx) (2.5.1)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas>=0.9->osmnx) (1.8.20)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx) (1.24.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->osmnx) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->osmnx) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx) (7.1.2)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx>=2.5->osmnx) (4.4.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (21.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (57.0.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (0.7.2)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (2.5.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (7.1.2)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (1.1.1)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (1.15.0)

# %%
import osmnx as ox
import networkx as nx
import numpy as np
from sklearn.neighbors import KDTree

# %% [markdown]
# We are going to local path planning in Berkeley, California, between the two nodes given below. After running the code up to and including the box below, you should see the output of the shortest path between the two points.

# %%
#from https://github.com/sidmitra/osmnx_playground

dist = 4*805 # radius in meters(approx 2 miles)
places = [
    ['delhi', (28.632821, 77.219459)], 
    ['mumbai', (18.932018, 72.834971)], 
    ['kolkatta', (22.566929, 88.347260)], 
    ['chennai', (13.080271, 80.284657)], 
    ['bengaluru', (12.977830, 77.593817)], 
    ['hyderabad', (17.366103, 78.469492)], 
    ['ahmedabad', (23.026948, 72.574903)], 
    ['jaipur', (26.907290, 75.805467)], 
    ['chandigarh', (30.732453, 76.772294)],
    ['pune', (18.519708, 73.856646)],
    ['lucknow', (26.845984, 80.946011)],
    ['gandhinagar', (23.224847, 72.646416)],   
]

# %%
name, point = places[6]
nt = 'drive_service'
map_graph = ox.graph_from_point(point, dist=dist,dist_type="bbox", network_type=nt, truncate_by_edge=True)
ox.plot_graph(map_graph, node_size=1, edge_color='orange', bgcolor='#000000', show=True)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# Print the edges and nodes of this graph

# %%
print(map_graph.nodes())
# Out:
# [245711252, 322863475, 322977408, 322977419, 322977422, 323119106, 323119241, 323119352, 323119354, 323120633, 323120854, 323121465, 323121657, 323122444, 323122550, 323122973, 323123060, 323123063, 323123182, 323123183, 323123186, 323123187, 323124553, 323124555, 323124562, 323126882, 323126897, 323126903, 323126905, 323127575, 323127625, 323127635, 323127641, 323127651, 323127653, 323128432, 323128434, 323129008, 323129508, 323131066, 325097963, 325097965, 325100428, 325101200, 335462378, 335462384, 335462388, 335462474, 335462475, 335462480, 335462481, 335465005, 335465019, 335465034, 335465061, 335465067, 335465076, 335465096, 335465168, 335466200, 335466223, 335466
# %% [markdown]
# Arbitrarily select the first node and last node in the Graph and find the shortest path

# %%
origin = 1792773169
destination = 6375354890
shortest_path = nx.shortest_path(map_graph,origin,destination)

# %% [markdown]
# Now visualize using plot_graph_route

# %%
fig, ax = ox.plot_graph_route(map_graph,shortest_path)

# %%
# Problem adapted from Introduction to AI, U of Toronto
# https://github.com/booklover98/A-star-Pathfinding

oshawa = (43.945403, -78.892466)
G = ox.graph_from_point(oshawa, dist=2000)
start = ox.geocode('2000 Simcoe St N, Oshawa, Ontario')
end = ox.geocode('18 Niagara Dr, Oshawa, Ontario')

#Convert the graph into geopandas dataframe
# easy to query closest node etc
nodes, _ = ox.graph_to_gdfs(G)

# %%
tree = KDTree(nodes[nodes.columns[0:2]].to_numpy(),leaf_size=2)
start_idx = tree.query(np.array([start]))[1][0][0]
end_idx = tree.query(np.array([end]))[1][0][0]

closest_start_node = nodes.iloc[start_idx][4]
closest_end_node = nodes.iloc[end_idx][4]

#retrieve origin and destination node id
origin = nodes.loc[nodes['geometry'] == closest_start_node].index[0]
destination = nodes.loc[nodes['geometry'] == closest_end_node].index[0]

# shortest path between source and destination
shortest_path = nx.shortest_path(G,origin,destination)

# %% [markdown]
# Visualize the shortest path and graph

# %%
#plot graph with geocodes and nodes
fig, ax = ox.plot_graph_route(G, shortest_path, figsize=(10,10), show=False, close=False, edge_color='black', route_color='green')
# ax.scatter(uoit[1], uoit[0], c='red', s=100)
# ax.scatter(address[1], address[0], c='blue', s=100)
# ax.scatter(closest_node_address['y'], closest_node_address['x'], c='green', s=100)
# ax.scatter(closest_node_uoit['y'], closest_node_uoit['x'], c='green', s=100)

# %% [markdown]
# Use these ideas to find shortest path between 2 addresses/ geocodes in an Indian city of your choice

# %%
mumbai = (18.932018, 72.834971)
G = ox.graph_from_point(mumbai, dist=2000)
start = ox.geocode('Chhatrapati Shivaji Maharaj Terminus, Mumbai, Maharashtra') # #Chhatrapati Shivaji Maharaj Railway Station
end = ox.geocode('Apollo Bandar, Colaba, Mumbai, Maharashtra')  ## Gateway of India
nodes, _ = ox.graph_to_gdfs(G)

# %%
tree = KDTree(nodes[nodes.columns[0:2]].to_numpy(),leaf_size=2)
start_idx = tree.query(np.array([start]))[1][0][0]
end_idx = tree.query(np.array([end]))[1][0][0]

closest_start_node = nodes.iloc[start_idx][4]
closest_end_node = nodes.iloc[end_idx][4]

#retrieve origin and destination node id
origin = nodes.loc[nodes['geometry'] == closest_start_node].index[0]
destination = nodes.loc[nodes['geometry'] == closest_end_node].index[0]

# shortest path between source and destination
shortest_path = nx.shortest_path(G,origin,destination)

# %%
fig, ax = ox.plot_graph_route(G, shortest_path, figsize=(10,10), show=False, close=False, edge_color='black', route_color='green')
