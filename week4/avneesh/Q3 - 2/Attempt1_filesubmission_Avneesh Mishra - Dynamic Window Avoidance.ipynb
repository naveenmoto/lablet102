# %%
import time
import toml
import numpy as np
import matplotlib.pyplot as plt
from ref_trajectory import generate_trajectory as traj
# %matplotlib inline

# %% [markdown]
# There are a lot of configuration parameters. It is a good idea to separate it from the main code. At some point you will be doing parameter tuning.
#
# We will use toml format to store parameters. Open config.toml and go over the description of the different parameters we may use here
#
# Read the config parameters, default output is a dictionary. You have to then store them as local variables.
# You have 2 options for this
# 1. update locals() directly - a little bit dangerous
# 2. You can use itemgetter

# %%
# !tree
# Out:
# .
# ├── __pycache__
# │   └── ref_trajectory.cpython-37.pyc
# ├── data
# │   ├── circuit.png
# │   └── config.toml
# └── ref_trajectory.py
#
# 2 directories, 4 files

# %%
config_params = toml.load("./data/config.toml")['params']
print(config_params)
# Out:
# {'dt': 0.1, 'V_MAX': 1.2, 'W_MAX': 1.0, 'K_MAX': 0.5, 'MIN_DIST': 1.0, 'ACC_MAX': 0.5, 'W_DOT_MAX': 3.0, 'LATERAL_ACC_MAX': 1.5, 'goal_threshold': 0.05, 'pred_horizon': 10, 'w_cte': 1.0, 'w_speed': 1.0}

# %%
from operator import itemgetter

dt, V_MAX, W_MAX, K_MAX, MIN_DIST, ACC_MAX, W_DOT_MAX, LATERAL_ACC_MAX, \
goal_threshold, pred_horizon, w_cte, w_speed = itemgetter("dt", "V_MAX", \
            "W_MAX", "K_MAX", "MIN_DIST", "ACC_MAX", "W_DOT_MAX", \
            "LATERAL_ACC_MAX", "goal_threshold", "pred_horizon", "w_cte", \
            "w_speed")(config_params)
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "import time\nimport toml\nimport numpy as np\nimport matplotlib.pyplot as plt\nfrom ref_trajectory import generate_trajectory as traj\nget_ipython().run_line_magic('matplotlib', 'inline')",
#   "get_ipython().system('tree')",
#   'config_params = toml.load("./data/config.toml")[\'params\']\nprint(config_params)',
#   'from operator import itemgetter\n\ndt, V_MAX, W_MAX, K_MAX, MIN_DIST, ACC_MAX, W_DOT_MAX, LATERAL_ACC_MAX, \\\ngoal_threshold, pred_horizon, w_cte, w_speed = itemgetter("dt", "V_MAX", \\\n            "W_MAX", "K_MAX", "MIN_DIST", "ACC_MAX", "W_DOT_MAX", \\\n            "LATERAL_ACC_MAX", "goal_threshold", "pred_horizon", "w_cte", \\\n            "w_speed")(config_params)\nlocals()'],
#  '_oh': {},
#  '_dh': ['/Users/avneesh/Documents/Courses/AP102/Week4'],
#  'In': ['',
#   "import time\nimport toml\nimport numpy as np\nimport matplotlib.pyplot as plt\nfrom ref_trajectory import generate_trajectory as traj\nget_ipython().run_line_magic('matplotlib', 'inline')",
#   "get_ipython().system('tree')",
#   'config_params = toml.load("./data/config.toml")[\'params\']\nprint(config_params)',
#   'from operator import itemgetter\n\ndt, V_MAX, W_MAX, K_MAX, MIN_DIST, ACC_MAX, W_DOT_MAX, LATERAL_ACC_MAX, \\\ngoal_threshold, pred_horizon, w_cte, w_speed = itemgetter("dt", "V_MAX", \\\n            "W_MAX", "K_MAX", "MIN_DIST", "ACC_MAX", "W_DOT_MAX", \\\n            "LATERAL_ACC_MAX", "goal_threshold", "pred_horizon", "w_cte", \\\n            "w_speed")(config_params)\nlocals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f873a5b64d0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f873a5e4750>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f873a5e4750>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': 'config_params = toml.load("./data/config.toml")[\'params\']\nprint(config_params)',
#  '_ii': '!tree',
#  '_iii': 'import time\nimport toml\nimport numpy as np\nimport matplotlib.pyplot as plt\nfrom ref_trajectory import generate_trajectory as traj\n%matplotlib inline',
#  '_i1': 'import time\nimport toml\nimport numpy as np\nimport matplotlib.pyplot as plt\nfrom ref_trajectory import generate_trajectory as traj\n%matplotlib inline',
#  'time': <module 'time' (built-in)>,
#  'toml': <module 'toml' from '/Users/avneesh/opt/anaconda3/envs/ap102/lib/python3.7/site-packages/toml/__init__.py'>,
#  'np': <module 'numpy' from '/Users/avneesh/opt/anaconda3/envs/ap102/lib/python3.7/site-packages/numpy/__init__.py'>,
#  'plt': <module 'matplotlib.pyplot' from '/Users/avneesh/opt/anaconda3/envs/ap102/lib/python3.7/site-packages/matplotlib/pyplot.py'>,
#  'traj': <function ref_trajectory.generate_trajectory(route, init_pose=(0, 0, 1.5707963267948966))>,
#  '_i2': '!tree',
#  '_exit_code': 0,
#  '_i3': 'config_params = toml.load("./data/config.toml")[\'params\']\nprint(config_params)',
#  'config_params': {'dt': 0.1,
#   'V_MAX': 1.2,
#   'W_MAX': 1.0,
#   'K_MAX': 0.5,
#   'MIN_DIST': 1.0,
#   'ACC_MAX': 0.5,
#   'W_DOT_MAX': 3.0,
#   'LATERAL_ACC_MAX': 1.5,
#   'goal_threshold': 0.05,
#   'pred_horizon': 10,
#   'w_cte': 1.0,
#   'w_speed': 1.0},
#  '_i4': 'from operator import itemgetter\n\ndt, V_MAX, W_MAX, K_MAX, MIN_DIST, ACC_MAX, W_DOT_MAX, LATERAL_ACC_MAX, \\\ngoal_threshold, pred_horizon, w_cte, w_speed = itemgetter("dt", "V_MAX", \\\n            "W_MAX", "K_MAX", "MIN_DIST", "ACC_MAX", "W_DOT_MAX", \\\n            "LATERAL_ACC_MAX", "goal_threshold", "pred_horizon", "w_cte", \\\n            "w_speed")(config_params)\nlocals()',
#  'itemgetter': operator.itemgetter,
#  'dt': 0.1,
#  'V_MAX': 1.2,
#  'W_MAX': 1.0,
#  'K_MAX': 0.5,
#  'MIN_DIST': 1.0,
#  'ACC_MAX': 0.5,
#  'W_DOT_MAX': 3.0,
#  'LATERAL_ACC_MAX': 1.5,
#  'goal_threshold': 0.05,
#  'pred_horizon': 10,
#  'w_cte': 1.0,
#  'w_speed': 1.0}

# %% [markdown]
# There are 3 functions we need to write for DWA
#
# 1. Simulate unicyle - we will slightly modify it to simulate $N$ steps
#
# 2. Command Window - Entire set of acceptable $(v, \omega)$ in that time instant given current $(v, \omega)$$
#
# 3. track - get $(v, \omega )$ for path with the lowest cost
#
# In the first iteration, let us not integrate collision checking. Let us integrate these pieces, make sure DWA works for a few paths!

# %%
v_min, v_max = 0.0, 0.2
w_min, w_max = -0.1, 0.1
vs = np.linspace(v_min, v_max, num=11)
ws = np.linspace(w_min, w_max, num=11)
cmd = np.transpose([np.tile(vs, len(ws)), np.repeat(ws, len(vs))])
print(vs)
# Out:
# [0.   0.02 0.04 0.06 0.08 0.1  0.12 0.14 0.16 0.18 0.2 ]

# %%
def simulate_unicycle(pose, v,w, N=1, dt=0.1):
  x, y, t = pose
  poses = []
  for _ in range(N):
    x += v*np.cos(t)*dt
    y += v*np.sin(t)*dt
    t += w*dt
    poses.append([x,y,t])
  return np.array(poses)

# %%
def command_window(v, w, dt=0.1):
  """Returns acceptable v,w commands given current v,w"""
  # velocity can be (0, V_MAX)
  # ACC_MAX = max linear acceleration
  v_max = min(V_MAX, v + ACC_MAX*dt)
  v_min = max(0, v - ACC_MAX*dt)
  # omega can be (-W_MAX, W_MAX)
  #W_DOT_MAX = max angular acceleration
  epsilon = 1e-6
  w_max = min(W_MAX, w + W_DOT_MAX*dt)
  w_min = max(-W_MAX, w - W_DOT_MAX*dt)
  
  #generate quantized range for v and omega
  vs = np.linspace(v_min, v_max, num=11)
  ws = np.linspace(w_min, w_max, num=21)
  
  #cartesian product of [vs] and [ws]
  #remember there are 0 velocity entries which have to be discarded eventually
  commands = np.transpose([np.tile(vs, len(ws)), np.repeat(ws, len(vs))])
  
  #calculate kappa for the set of commands
  kappa = commands[:,1]/(commands[:,0]+epsilon)
  
  #returning only commands < max curvature 
  return commands[(kappa < K_MAX) & (commands[:, 0] != 0)]

# %%
def euclidean(p1, p2):
  x1, y1 = p1
  x2, y2 = p2
  return ((x1 - x2)**2 + (y1 - y2)**2)**0.5

# %%
def track(ref_path, pose, v, w, dt=0.1):
  commands = command_window(v, w, dt) # Got command values, (v, w) pairs
  #initialize path cost
  best_cost, best_command = np.inf, None
  for i, (v, w) in enumerate(commands):
    local_path = simulate_unicycle(pose, v, w, N=pred_horizon, dt=dt) #Number of steps = prediction horizon
    
    # if circle_collision_check(grid, local_path): #ignore colliding paths
    #   print("local path has a collision")
    #   continue
    
    #calculate cross-track error
    #can use a simplistic definition of 
    #how close is the last pose in local path from the ref path

    cte = euclidean(local_path[-1][:2], ref_path[-1][:2])
    
    #other cost functions are possible
    #can modify collision checker to give distance to closest obstacle
    cost = w_cte*cte + w_speed*(V_MAX - v)**2
    
    #check if there is a better candidate
    if cost < best_cost:
      best_cost, best_command = cost, (v, w)

  if best_command:
    return best_command
  else:
    return [0, 0]

# %%
start_pose = np.array([0, 0, np.pi/2])
route = [("straight", 5),("turn", -90),("straight", 6),("turn", 90)]
x_ref, y_ref, th_ref = traj(route, start_pose)
ref_path = np.array([x_ref, y_ref, th_ref]).T

# %%
pose = start_pose
logs = []
path_index = 0
v, w = 0.0, 0.0
while path_index < len(ref_path)-1:
    t0 = time.time()
    local_ref_path = ref_path[path_index:path_index+pred_horizon]
    # update path_index using current pose and local_ref_path
    path_index = path_index + 1 \
      if euclidean(pose[:2], local_ref_path[-1][:2]) < goal_threshold * 10 \
      else path_index

    # get next command
    v, w = track(local_ref_path, pose, v, w)
    
    #simulate vehicle for 1 step
    # remember the function now returns a trajectory, not a single pose
    pose = simulate_unicycle(pose, v, w)[-1]
    
    #update logs
    logs.append([*pose, v, w])
    t1 = time.time() #simplest way to time-profile your code
    print(f"idx:{path_index}, v:{v:0.3f}, w:{w:0.3f}, time:{(t1-t0) * 1000:0.1f}ms")
# Out:
# idx:0, v:0.050, w:0.000, time:16.8ms
# idx:0, v:0.100, w:0.000, time:23.3ms
# idx:0, v:0.150, w:0.000, time:31.1ms
# idx:0, v:0.200, w:0.000, time:31.8ms
# idx:0, v:0.250, w:0.000, time:55.1ms
# idx:0, v:0.300, w:0.000, time:36.6ms
# idx:0, v:0.350, w:0.000, time:30.2ms
# idx:0, v:0.400, w:0.000, time:29.2ms
# idx:0, v:0.450, w:0.000, time:32.9ms
# idx:0, v:0.500, w:0.000, time:30.6ms
# idx:0, v:0.550, w:0.000, time:31.9ms
# idx:0, v:0.600, w:0.000, time:28.9ms
# idx:0, v:0.650, w:0.000, time:32.1ms
# idx:0, v:0.700, w:0.000, time:32.9ms
# idx:0, v:0.750, w:0.000, time:23.6ms
# idx:0, v:0.800, w:0.000, time:23.4ms
# idx:0, v:0.850, w:0.000, time:37.7ms
# idx:0, v:0.900, w:0.000, time:42.2ms
# idx:0, v:0.950, w:0.000, time:39.9ms
# idx:0, v:1.000, w:0.000, time:65.1ms
# idx:0, v:1.050, w:0.000, time:25.7ms
# idx:0, v:1.100, w:0.000, time:22.8ms
# idx:0, v:1.150, w:0.000, time:23.3ms
# idx:0, v:1.200, w:0.000, time:30.2ms
# idx:0, v:1.200, w:0.000, time:26.4ms
# idx:0, v:1.200, w:0.000, time:23.2ms
# idx:0, v:1.200, w:0.000, time:20.8ms
# idx:0, v:1.200, w:0.000, time:26.5ms
# idx:0, v:1.200, w:0.000, time:24.1ms
# idx:0, v:1.200, w:0.000, time:23.0ms
# idx:0, v:1.200, w:0.000, time:18.7ms
# idx:0, v:1.200, w:0.000, time:21.9ms
# idx:0, v:1.200, w:0.000, time:19.3ms
# idx:0, v:1.200, w:0.000, time:37.4ms
# idx:0, v:1.200, w:0.000, time:26.5ms
# idx:0, v:1.200, w:0.000, time:25.0ms
# idx:0, v:1.200, w:0.000, time:26.5ms
# idx:0, v:1.200, w:0.000, time:25.8ms
# idx:0, v:1.200, w:0.000, time:37.4ms
# idx:0, v:1.200, w:0.000, time:39.8ms
# idx:0, v:1.200, w:0.000, time:26.6ms
# idx:0, v:1.200, w:0.000, time:20.1ms
# idx:0, v:1.200, w:0.000, time:17.0ms
# idx:0, v:1.200, w:0.000, time:18.0ms
# idx:0, v:1.150, w:0.000, time:16.9ms
# idx:0, v:1.100, w:0.000, time:17.3ms
# idx:0, v:1.050, w:0.000, time:22.9ms
# idx:0, v:1.000, w:0.000, time:16.1ms
# idx:0, v:0.950, w:0.000, time:17.2ms
# idx:0, v:0.900, w:0.000, time:22.8ms
# idx:1, v:0.850, w:0.000, time:30.2ms
# idx:2, v:0.800, w:0.000, time:134.2ms
# idx:2, v:0.750, w:0.000, time:41.0ms
# idx:3, v:0.700, w:0.000, time:41.4ms
# idx:4, v:0.700, w:0.000, time:34.0ms
# idx:4, v:0.700, w:0.000, time:51.9ms
# idx:5, v:0.700, w:-0.030, time:22.9ms
# idx:6, v:0.700, w:-0.030, time:29.8ms
# idx:7, v:0.700, w:-0.030, time:21.4ms
# idx:7, v:0.700, w:-0.060, time:19.0ms
# idx:8, v:0.700, w:-0.060, time:19.2ms
# idx:9, v:0.700, w:-0.060, time:18.3ms
# idx:9, v:0.700, w:-0.090, time:18.9ms
# idx:10, v:0.700, w:-0.090, time:21.5ms
# idx:11, v:0.700, w:-0.120, time:25.2ms
# idx:11, v:0.700, w:-0.150, time:29.5ms
# idx:12, v:0.700, w:-0.150, time:26.5ms
# idx:13, v:0.700, w:-0.150, time:18.4ms
# idx:14, v:0.700, w:-0.180, time:17.1ms
# idx:14, v:0.700, w:-0.210, time:16.6ms
# idx:15, v:0.700, w:-0.210, time:16.5ms
# idx:16, v:0.700, w:-0.210, time:15.5ms
# idx:16, v:0.700, w:-0.240, time:19.6ms
# idx:17, v:0.700, w:-0.240, time:15.9ms
# idx:18, v:0.700, w:-0.240, time:15.2ms
# idx:18, v:0.700, w:-0.270, time:21.1ms
# idx:19, v:0.700, w:-0.270, time:18.0ms
# idx:20, v:0.700, w:-0.300, time:17.0ms
# idx:21, v:0.700, w:-0.300, time:17.4ms
# idx:21, v:0.700, w:-0.300, time:17.0ms
# idx:22, v:0.700, w:-0.300, time:15.5ms
# idx:23, v:0.700, w:-0.300, time:15.7ms
# idx:23, v:0.700, w:-0.330, time:20.2ms
# idx:24, v:0.700, w:-0.330, time:30.3ms
# idx:25, v:0.700, w:-0.330, time:32.3ms
# idx:25, v:0.700, w:-0.330, time:30.3ms
# idx:26, v:0.700, w:-0.330, time:28.9ms
# idx:27, v:0.700, w:-0.330, time:19.3ms
# idx:28, v:0.700, w:-0.330, time:30.0ms
# idx:28, v:0.700, w:-0.330, time:16.6ms
# idx:29, v:0.700, w:-0.330, time:18.5ms
# idx:30, v:0.700, w:-0.330, time:15.1ms
# idx:30, v:0.700, w:-0.330, time:14.6ms
# idx:31, v:0.700, w:-0.330, time:18.2ms
# idx:32, v:0.700, w:-0.330, time:18.6ms
# idx:32, v:0.700, w:-0.330, time:19.1ms
# idx:33, v:0.700, w:-0.330, time:19.5ms
# idx:34, v:0.700, w:-0.330, time:14.9ms
# idx:34, v:0.700, w:-0.330, time:15.9ms
# idx:35, v:0.700, w:-0.330, time:23.2ms
# idx:36, v:0.700, w:-0.330, time:24.9ms
# idx:37, v:0.700, w:-0.300, time:17.3ms
# idx:37, v:0.700, w:-0.300, time:16.6ms
# idx:38, v:0.700, w:-0.300, time:15.1ms
# idx:39, v:0.700, w:-0.300, time:14.7ms
# idx:39, v:0.700, w:-0.300, time:14.5ms
# idx:40, v:0.700, w:-0.300, time:14.4ms
# idx:41, v:0.700, w:-0.270, time:15.8ms
# idx:41, v:0.700, w:-0.270, time:16.0ms
# idx:42, v:0.700, w:-0.270, time:15.0ms
# idx:43, v:0.700, w:-0.240, time:14.7ms
# idx:44, v:0.700, w:-0.210, time:14.6ms
# idx:44, v:0.700, w:-0.210, time:14.6ms
# idx:45, v:0.700, w:-0.210, time:16.1ms
# idx:46, v:0.700, w:-0.180, time:15.4ms
# idx:46, v:0.700, w:-0.180, time:16.9ms
# idx:47, v:0.700, w:-0.180, time:16.8ms
# idx:48, v:0.700, w:-0.150, time:15.9ms
# idx:48, v:0.700, w:-0.150, time:14.7ms
# idx:49, v:0.700, w:-0.150, time:14.5ms
# idx:50, v:0.700, w:-0.120, time:15.2ms
# idx:51, v:0.700, w:-0.090, time:15.2ms
# idx:52, v:0.700, w:-0.090, time:15.7ms
# idx:52, v:0.750, w:-0.030, time:15.5ms
# idx:52, v:0.800, w:-0.030, time:15.4ms
# idx:52, v:0.850, w:-0.030, time:15.2ms
# idx:52, v:0.800, w:-0.030, time:15.0ms
# idx:52, v:0.750, w:-0.030, time:15.5ms
# idx:52, v:0.700, w:0.000, time:16.1ms
# idx:52, v:0.700, w:-0.030, time:19.2ms
# idx:53, v:0.700, w:0.000, time:27.7ms
# idx:53, v:0.750, w:0.000, time:19.3ms
# idx:53, v:0.800, w:0.000, time:17.0ms
# idx:53, v:0.850, w:0.000, time:14.6ms
# idx:53, v:0.850, w:0.000, time:14.5ms
# idx:53, v:0.800, w:0.000, time:14.6ms
# idx:53, v:0.750, w:0.030, time:16.8ms
# idx:53, v:0.700, w:0.000, time:15.4ms
# idx:53, v:0.700, w:0.000, time:16.7ms
# idx:54, v:0.700, w:0.030, time:15.2ms
# idx:54, v:0.750, w:0.000, time:14.5ms
# idx:54, v:0.800, w:0.000, time:15.5ms
# idx:54, v:0.850, w:0.000, time:21.8ms
# idx:54, v:0.830, w:0.000, time:22.8ms
# idx:54, v:0.780, w:0.000, time:15.8ms
# idx:54, v:0.730, w:0.030, time:15.0ms
# idx:54, v:0.700, w:0.000, time:18.9ms
# idx:54, v:0.700, w:0.000, time:16.2ms
# idx:55, v:0.700, w:0.030, time:15.8ms
# idx:55, v:0.750, w:0.000, time:18.6ms
# idx:55, v:0.800, w:0.000, time:15.3ms
# idx:55, v:0.850, w:0.000, time:15.2ms
# idx:55, v:0.810, w:0.000, time:16.4ms
# idx:55, v:0.760, w:0.000, time:18.3ms
# idx:55, v:0.710, w:0.000, time:17.2ms
# idx:55, v:0.700, w:0.000, time:18.5ms
# idx:55, v:0.700, w:0.000, time:16.2ms
# idx:56, v:0.700, w:0.000, time:16.8ms
# idx:56, v:0.750, w:0.000, time:15.9ms
# idx:56, v:0.800, w:0.000, time:16.7ms
# idx:56, v:0.850, w:0.000, time:19.0ms
# idx:56, v:0.800, w:0.000, time:15.5ms
# idx:56, v:0.750, w:0.000, time:16.2ms
# idx:56, v:0.700, w:0.000, time:15.0ms
# idx:56, v:0.700, w:0.000, time:17.3ms
# idx:56, v:0.700, w:0.000, time:14.8ms
# idx:57, v:0.700, w:0.000, time:14.7ms
# idx:57, v:0.750, w:0.000, time:25.6ms
# idx:57, v:0.800, w:0.000, time:28.8ms
# idx:57, v:0.850, w:0.000, time:15.4ms
# idx:57, v:0.800, w:0.000, time:16.2ms
# idx:57, v:0.750, w:0.000, time:14.6ms
# idx:57, v:0.700, w:0.000, time:16.0ms
# idx:57, v:0.700, w:0.000, time:17.1ms
# idx:58, v:0.700, w:0.000, time:15.4ms
# idx:58, v:0.750, w:0.000, time:16.1ms
# idx:58, v:0.800, w:0.000, time:15.0ms
# idx:58, v:0.850, w:0.000, time:14.6ms
# idx:58, v:0.850, w:0.000, time:15.8ms
# idx:58, v:0.800, w:0.000, time:15.6ms
# idx:58, v:0.750, w:0.000, time:16.8ms
# idx:58, v:0.700, w:0.000, time:14.9ms
# idx:58, v:0.700, w:-0.030, time:14.7ms
# idx:59, v:0.700, w:0.000, time:17.5ms
# idx:59, v:0.750, w:0.000, time:17.9ms
# idx:59, v:0.800, w:0.000, time:15.8ms
# idx:59, v:0.850, w:0.000, time:14.8ms
# idx:59, v:0.830, w:0.000, time:15.1ms
# idx:59, v:0.780, w:0.000, time:14.5ms
# idx:59, v:0.730, w:0.000, time:16.2ms
# idx:59, v:0.700, w:0.000, time:17.5ms
# idx:59, v:0.700, w:0.000, time:15.9ms
# idx:60, v:0.700, w:0.000, time:15.4ms
# idx:60, v:0.750, w:0.000, time:14.8ms
# idx:60, v:0.800, w:0.000, time:14.8ms
# idx:60, v:0.850, w:0.000, time:15.3ms
# idx:60, v:0.810, w:0.000, time:17.3ms
# idx:60, v:0.760, w:0.000, time:14.7ms
# idx:60, v:0.710, w:0.000, time:27.0ms
# idx:60, v:0.700, w:0.000, time:38.0ms
# idx:60, v:0.700, w:0.000, time:43.1ms
# idx:61, v:0.700, w:0.000, time:39.2ms
# idx:62, v:0.700, w:0.000, time:32.5ms
# idx:63, v:0.700, w:0.000, time:19.8ms
# idx:63, v:0.700, w:0.000, time:19.1ms
# idx:64, v:0.700, w:0.000, time:16.5ms
# idx:65, v:0.700, w:0.030, time:15.0ms
# idx:65, v:0.700, w:0.030, time:15.0ms
# idx:66, v:0.700, w:0.030, time:14.4ms
# idx:67, v:0.700, w:0.030, time:15.0ms
# idx:67, v:0.700, w:0.060, time:15.1ms
# idx:68, v:0.700, w:0.060, time:15.1ms
# idx:69, v:0.700, w:0.060, time:14.6ms
# idx:70, v:0.700, w:0.090, time:14.5ms
# idx:70, v:0.700, w:0.120, time:19.0ms
# idx:71, v:0.700, w:0.120, time:12.6ms
# idx:72, v:0.700, w:0.120, time:13.0ms
# idx:72, v:0.700, w:0.150, time:13.5ms
# idx:73, v:0.700, w:0.150, time:24.0ms
# idx:74, v:0.700, w:0.180, time:15.9ms
# idx:74, v:0.700, w:0.210, time:12.9ms
# idx:75, v:0.700, w:0.210, time:12.5ms
# idx:76, v:0.700, w:0.240, time:11.4ms
# idx:77, v:0.700, w:0.240, time:10.6ms
# idx:77, v:0.700, w:0.270, time:10.9ms
# idx:78, v:0.700, w:0.240, time:10.3ms
# idx:79, v:0.700, w:0.270, time:14.1ms
# idx:79, v:0.700, w:0.270, time:11.6ms
# idx:80, v:0.700, w:0.270, time:11.6ms
# idx:81, v:0.700, w:0.300, time:14.0ms
# idx:81, v:0.700, w:0.300, time:9.1ms
# idx:82, v:0.700, w:0.300, time:9.7ms
# idx:83, v:0.700, w:0.300, time:8.5ms
# idx:83, v:0.700, w:0.330, time:8.5ms
# idx:84, v:0.700, w:0.330, time:8.0ms
# idx:85, v:0.700, w:0.330, time:7.7ms
# idx:86, v:0.700, w:0.330, time:15.5ms
# idx:86, v:0.700, w:0.330, time:9.7ms
# idx:87, v:0.700, w:0.330, time:8.8ms
# idx:88, v:0.700, w:0.330, time:13.0ms
# idx:88, v:0.700, w:0.330, time:11.3ms
# idx:89, v:0.700, w:0.330, time:12.4ms
# idx:90, v:0.700, w:0.330, time:11.2ms
# idx:90, v:0.700, w:0.330, time:8.8ms
# idx:91, v:0.700, w:0.330, time:8.8ms
# idx:92, v:0.700, w:0.330, time:8.5ms
# idx:93, v:0.700, w:0.330, time:7.9ms
# idx:93, v:0.700, w:0.330, time:8.1ms
# idx:94, v:0.700, w:0.330, time:9.9ms
# idx:95, v:0.700, w:0.330, time:12.0ms
# idx:95, v:0.700, w:0.330, time:10.3ms
# idx:96, v:0.700, w:0.330, time:10.8ms
# idx:97, v:0.700, w:0.330, time:8.8ms
# idx:97, v:0.700, w:0.330, time:9.4ms
# idx:98, v:0.700, w:0.330, time:8.6ms
# idx:99, v:0.700, w:0.300, time:10.4ms
# idx:99, v:0.700, w:0.270, time:13.6ms
# idx:100, v:0.700, w:0.300, time:25.2ms
# idx:101, v:0.700, w:0.270, time:12.0ms
# idx:102, v:0.700, w:0.240, time:10.8ms
# idx:102, v:0.700, w:0.240, time:11.0ms
# idx:103, v:0.700, w:0.240, time:11.1ms
# idx:104, v:0.700, w:0.210, time:11.5ms
# idx:104, v:0.700, w:0.210, time:11.6ms
# idx:105, v:0.700, w:0.210, time:12.7ms
# idx:106, v:0.700, w:0.180, time:12.8ms
# idx:106, v:0.700, w:0.180, time:17.7ms
# idx:107, v:0.700, w:0.180, time:14.2ms
# idx:108, v:0.700, w:0.150, time:17.7ms
# idx:109, v:0.700, w:0.150, time:13.3ms
# idx:109, v:0.700, w:0.120, time:13.5ms
# idx:110, v:0.700, w:0.120, time:17.4ms
# idx:111, v:0.700, w:0.090, time:19.6ms
# idx:112, v:0.700, w:0.090, time:15.0ms
# idx:113, v:0.700, w:0.090, time:13.8ms
# idx:114, v:0.700, w:0.150, time:23.9ms
# idx:115, v:0.700, w:0.330, time:15.3ms
# idx:116, v:0.700, w:0.330, time:12.7ms
# idx:117, v:0.720, w:0.360, time:10.0ms
# idx:118, v:0.720, w:0.360, time:9.4ms
# idx:119, v:0.720, w:0.360, time:8.3ms

# %%
poses = np.array(logs)[:,:3]
plt.figure()
plt.axes().set_aspect('equal', 'datalim')
plt.plot(ref_path[:,0], ref_path[:,1], '.', c='g')
plt.plot(poses[:,0], poses[:,1], c='r')

# %% [markdown]
# Now it should be relatively straight-forward to integrate collision checking in the grid environment the robot is going to navigate
