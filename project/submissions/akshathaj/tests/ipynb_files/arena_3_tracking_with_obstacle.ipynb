# %%
import time
import toml
import numpy as np
import matplotlib.pyplot as plt
from ref_trajectory import plot_smooth_route
from ref_trajectory import generate_trajectory as traj
from astar import gen_astar_path, plot_astar
from route_directions import make_route,euclidean
from collision_dwa import simulate_unicycle,track,plot_final_path,plot_wvk
from environment_setup import grid_from_map,place_obstacles,plot_environment,densify_grid
# %matplotlib inline

config_params = toml.load("config.toml")['params']
locals().update(config_params)

# %%
data = np.loadtxt("arena_3.map", skiprows=4, dtype='str')
data_header = np.loadtxt("arena_3.map", skiprows=1, max_rows = 2, dtype = 'str')
data_size = [int(data_header[0][1]), int(data_header[1][1])]
grid = grid_from_map(data,data_size)
start = (17,39)
goal = (26,14)
astar_path,extent_limits = gen_astar_path(grid,start,goal)
plot_astar(grid,start,goal,astar_path,extent_limits)

# %%
grid_dense = densify_grid(grid)
plot_astar(grid_dense,start,goal,astar_path,extent_limits)

# %%
obstacles = np.array([[22, 24, 31, 33],
                       [10, 15, 5, 7]])
grid_modified = place_obstacles(grid,obstacles,extent_limits)
grid_modified_dense = densify_grid(grid_modified)
# plot_environment(grid_modified_dense,extent_limits)
plot_astar(grid_modified_dense,start,goal,astar_path,extent_limits)

# %%
pose = (*astar_path[0],0)
logs = []
path_index = 0
v, w = 0.0, 0.0
while path_index < len(astar_path)-1:
    t0 = time.time()
    local_ref_path = astar_path[path_index:path_index+pred_horizon]
    # update path_index using current pose and local_ref_path
    if euclidean(pose[:2],local_ref_path[-1][:2]) < goal_threshold*4*pred_horizon:
        path_index = path_index + 1
        local_ref_path = astar_path[path_index:path_index+pred_horizon]
    # get next command
    v, w = track(grid_modified_dense,local_ref_path,pose,v,w)
    
    #simulate vehicle for 1 step
    # remember the function now returns a trajectory, not a single pose
    pose = simulate_unicycle(pose,v,w)[-1]
    
    #update logs
    logs.append([*pose, v, w, local_ref_path[-1]])
    t1 = time.time() #simplest way to time-profile your code
    print(f"idx:{path_index}, v:{v:0.3f}, w:{w:0.3f}, current pose: {pose}, tracking point:{local_ref_path[-1][:2]}, time:{(t1-t0) * 1000:0.1f}ms")
# Out:
# Streaming output truncated to the last 5000 lines.
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = (1.1549999999999998, 0.14020000000000077), cost = 5.980698747196874
# local path has a collision, best_command = (1.1549999999999998, 0.14020000000000077), cost = 5.980698747196874
# local path has a collision, best_command = (1.1549999999999998, 0.14020000000000077), cost = 5.980698747196874
# local path has a collision, best_command = (1.1549999999999998, 0.14020000000000077), cost = 5.980698747196874
# local path has a collision, best_command = (1.1549999999999998, 0.14020000000000077), cost = 5.980698747196874
# local path has a collision, best_command = (1.1549999999999998, 0.14020000000000077), cost = 5.980698747196874
# local path has a collision, best_command = (1.1549999999999998, 0.14020000000000077), cost = 5.980698747196874
# local path has a collision, best_command = (1.165, 0.11020000000000074), cost = 5.968539752526936
# local path has a collision, best_command = (1.165, 0.11020000000000074), cost = 5.968539752526936
# local path has a collision, best_command = (1.165, 0.11020000000000074), cost = 5.968539752526936
# local path has a collision, best_command = (1.165, 0.11020000000000074), cost = 5.968539752526936
# local path has a collision, best_command = (1.18, 0.08020000000000077), cost = 5.9516762415255755
# local path has a collision, best_command = (1.18, 0.08020000000000077), cost = 5.9516762415255755
# idx:0, v:1.200, w:-0.010, current pose: [20.50152831 35.37636673 -0.8763    ], tracking point:(25, 30), time:559.1ms
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = (1.15, 0.20020000000000082), cost = 5.8697980543619765
# local path has a collision, best_command = (1.15, 0.20020000000000082), cost = 5.8697980543619765
# local path has a collision, best_command = (1.15, 0.20020000000000082), cost = 5.8697980543619765
# local path has a collision, best_command = (1.15, 0.20020000000000082), cost = 5.8697980543619765
# local path has a collision, best_command = (1.15, 0.20020000000000082), cost = 5.8697980543619765
# local path has a collision, best_command = (1.15, 0.20020000000000082), cost = 5.8697980543619765
# local path has a collision, best_command = (1.15, 0.20020000000000082), cost = 5.8697980543619765
# local path has a collision, best_command = (1.15, 0.20020000000000082), cost = 5.8697980543619765
# local path has a collision, best_command = (1.16, 0.1702000000000008), cost = 5.856924415482263
# local path has a collision, best_command = (1.16, 0.1702000000000008), cost = 5.856924415482263
# local path has a collision, best_command = (1.16, 0.1702000000000008), cost = 5.856924415482263
# local path has a collision, best_command = (1.16, 0.1702000000000008), cost = 5.856924415482263
# local path has a collision, best_command = (1.16, 0.1702000000000008), cost = 5.856924415482263
# local path has a collision, best_command = (1.16, 0.1702000000000008), cost = 5.856924415482263
# local path has a collision, best_command = (1.17, 0.14020000000000077), cost = 5.844549793814297
# local path has a collision, best_command = (1.17, 0.14020000000000077), cost = 5.844549793814297
# local path has a collision, best_command = (1.17, 0.14020000000000077), cost = 5.844549793814297
# local path has a collision, best_command = (1.17, 0.14020000000000077), cost = 5.844549793814297
# local path has a collision, best_command = (1.18, 0.1102000000000008), cost = 5.832685178050288
# local path has a collision, best_command = (1.18, 0.1102000000000008), cost = 5.832685178050288
# idx:0, v:1.200, w:-0.010, current pose: [20.57832813 35.28416159 -0.87728   ], tracking point:(25, 30), time:546.4ms
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = (1.1549999999999998, 0.26020000000000076), cost = 5.749297280693088
# local path has a collision, best_command = (1.1549999999999998, 0.26020000000000076), cost = 5.749297280693088
# local path has a collision, best_command = (1.1549999999999998, 0.26020000000000076), cost = 5.749297280693088
# local path has a collision, best_command = (1.1549999999999998, 0.26020000000000076), cost = 5.749297280693088
# local path has a collision, best_command = (1.1549999999999998, 0.26020000000000076), cost = 5.749297280693088
# local path has a collision, best_command = (1.1549999999999998, 0.26020000000000076), cost = 5.749297280693088
# local path has a collision, best_command = (1.1549999999999998, 0.26020000000000076), cost = 5.749297280693088
# local path has a collision, best_command = (1.165, 0.23020000000000085), cost = 5.735903957842011
# local path has a collision, best_command = (1.165, 0.23020000000000085), cost = 5.735903957842011
# local path has a collision, best_command = (1.165, 0.23020000000000085), cost = 5.735903957842011
# local path has a collision, best_command = (1.165, 0.23020000000000085), cost = 5.735903957842011
# local path has a collision, best_command = (1.165, 0.23020000000000085), cost = 5.735903957842011
# local path has a collision, best_command = (1.165, 0.23020000000000085), cost = 5.735903957842011
# local path has a collision, best_command = (1.17, 0.20020000000000082), cost = 5.7282357286771175
# local path has a collision, best_command = (1.17, 0.20020000000000082), cost = 5.7282357286771175
# local path has a collision, best_command = (1.17, 0.20020000000000082), cost = 5.7282357286771175
# local path has a collision, best_command = (1.17, 0.20020000000000082), cost = 5.7282357286771175
# local path has a collision, best_command = (1.18, 0.1702000000000008), cost = 5.715735027944377
# local path has a collision, best_command = (1.18, 0.1702000000000008), cost = 5.715735027944377
# local path has a collision, best_command = (1.19, 0.14020000000000077), cost = 5.703740934206648
# idx:0, v:1.200, w:0.020, current pose: [20.65503756 35.19188123 -0.87526   ], tracking point:(25, 30), time:562.9ms
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = (1.17, 0.3202000000000008), cost = 5.620253120177149
# local path has a collision, best_command = (1.17, 0.3202000000000008), cost = 5.620253120177149
# local path has a collision, best_command = (1.17, 0.3202000000000008), cost = 5.620253120177149
# local path has a collision, best_command = (1.17, 0.3202000000000008), cost = 5.620253120177149
# local path has a collision, best_command = (1.17, 0.3202000000000008), cost = 5.620253120177149
# local path has a collision, best_command = (1.1749999999999998, 0.2902000000000008), cost = 5.611614362245699
# local path has a collision, best_command = (1.1749999999999998, 0.2902000000000008), cost = 5.611614362245699
# local path has a collision, best_command = (1.1749999999999998, 0.2902000000000008), cost = 5.611614362245699
# local path has a collision, best_command = (1.185, 0.2602000000000009), cost = 5.598216881165683
# local path has a collision, best_command = (1.185, 0.2602000000000009), cost = 5.598216881165683
# local path has a collision, best_command = (1.19, 0.23020000000000085), cost = 5.590328357488905
# idx:0, v:1.200, w:-0.010, current pose: [20.73193323 35.09975601 -0.87624   ], tracking point:(25, 30), time:550.8ms
# idx:0, v:1.200, w:-0.010, current pose: [20.80873858 35.00755548 -0.87722   ], tracking point:(25, 30), time:586.5ms
# idx:0, v:1.200, w:0.020, current pose: [20.88545354 34.91527973 -0.8752    ], tracking point:(25, 30), time:575.7ms
# idx:0, v:1.200, w:-0.010, current pose: [20.96235474 34.82315913 -0.87618   ], tracking point:(25, 30), time:585.6ms
# idx:0, v:1.200, w:-0.010, current pose: [21.03916563 34.73096321 -0.87716   ], tracking point:(25, 30), time:572.4ms
# idx:0, v:1.200, w:0.020, current pose: [21.11588612 34.63869205 -0.87514   ], tracking point:(25, 30), time:576.8ms
# idx:0, v:1.200, w:-0.010, current pose: [21.19279285 34.54657607 -0.87612   ], tracking point:(25, 30), time:574.3ms
# idx:0, v:1.200, w:-0.010, current pose: [21.26960927 34.45438475 -0.8771    ], tracking point:(25, 30), time:565.0ms
# idx:0, v:1.200, w:0.020, current pose: [21.3463353 34.3621182 -0.87508  ], tracking point:(25, 30), time:591.4ms
# idx:0, v:1.200, w:-0.010, current pose: [21.42324755 34.27000683 -0.87606   ], tracking point:(25, 30), time:571.2ms
# idx:0, v:1.200, w:-0.010, current pose: [21.5000695  34.17782013 -0.87704   ], tracking point:(25, 30), time:588.3ms
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# local path has a collision, best_command = (1.2, 0.020200000000000995), cost = 4.2501531645623
# idx:0, v:1.200, w:0.020, current pose: [21.57680107 34.08555818 -0.87502   ], tracking point:(25, 30), time:622.7ms
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# local path has a collision, best_command = (1.2, 0.11020000000000102), cost = 4.132490026495983
# idx:0, v:1.200, w:0.110, current pose: [21.65371885 33.99345142 -0.864     ], tracking point:(25, 30), time:692.3ms
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# local path has a collision, best_command = (1.2, 0.26020000000000104), cost = 4.025839880289075
# idx:0, v:1.200, w:0.260, current pose: [21.73164696 33.90219788 -0.83798   ], tracking point:(25, 30), time:702.3ms
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# local path has a collision, best_command = (1.2, 0.3802000000000011), cost = 3.9302741829907504
# ...
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# local path has a collision, best_command = (1.1905000000000001, 0.44375000000000103), cost = 1.2705727706289482
# idx:5, v:1.191, w:0.444, current pose: [22.96096615 27.11032398 -2.304     ], tracking point:(22, 25), time:577.5ms
# idx:5, v:1.200, w:0.564, current pose: [22.88065573 27.02115988 -2.247625  ], tracking point:(22, 25), time:589.4ms
# idx:5, v:1.200, w:0.504, current pose: [22.80549686 26.92761233 -2.19725   ], tracking point:(22, 25), time:592.7ms
# idx:5, v:1.200, w:0.444, current pose: [22.7351438  26.83039892 -2.152875  ], tracking point:(22, 25), time:601.6ms
# idx:6, v:1.200, w:0.594, current pose: [22.66917242 26.73016032 -2.0935    ], tracking point:(22, 24), time:591.2ms
# idx:6, v:1.200, w:0.504, current pose: [22.60926547 26.62618361 -2.043125  ], tracking point:(22, 24), time:596.5ms
# idx:6, v:1.200, w:0.444, current pose: [22.55467012 26.51932226 -1.99875   ], tracking point:(22, 24), time:579.6ms
# idx:6, v:1.200, w:0.384, current pose: [22.50486893 26.41014423 -1.960375  ], tracking point:(22, 24), time:590.5ms
# idx:6, v:1.200, w:0.324, current pose: [22.45929309 26.29913593 -1.928     ], tracking point:(22, 24), time:601.4ms
# idx:6, v:1.200, w:0.294, current pose: [22.41733439 26.18671054 -1.898625  ], tracking point:(22, 24), time:561.2ms
# idx:6, v:1.200, w:0.264, current pose: [22.37869582 26.0731013  -1.87225   ], tracking point:(22, 24), time:562.3ms
# idx:6, v:1.200, w:0.234, current pose: [22.34306679 25.95851259 -1.848875  ], tracking point:(22, 24), time:587.3ms
# idx:7, v:1.200, w:0.534, current pose: [22.31012575 25.84312243 -1.7955    ], tracking point:(23, 23), time:560.9ms
# idx:7, v:1.200, w:0.834, current pose: [22.28338765 25.72613921 -1.712125  ], tracking point:(23, 23), time:579.6ms
# idx:7, v:1.200, w:0.720, current pose: [22.26648461 25.60733565 -1.6401    ], tracking point:(23, 23), time:606.6ms
# idx:7, v:1.200, w:0.623, current pose: [22.25817483 25.48762371 -1.57778375], tracking point:(23, 23), time:571.2ms
# idx:7, v:1.200, w:0.533, current pose: [22.25733634 25.36762664 -1.5244675 ], tracking point:(23, 23), time:589.9ms
# idx:7, v:1.200, w:0.473, current pose: [22.26289381 25.2477554  -1.47715125], tracking point:(23, 23), time:590.4ms
# idx:7, v:1.200, w:0.413, current pose: [22.2741148  25.12828118 -1.435835  ], tracking point:(23, 23), time:583.0ms
# idx:7, v:1.200, w:0.353, current pose: [22.29026104 25.00937239 -1.40051875], tracking point:(23, 23), time:577.8ms
# idx:7, v:1.200, w:0.323, current pose: [22.31059575 24.89110786 -1.3682025 ], tracking point:(23, 23), time:567.7ms
# idx:7, v:1.200, w:0.293, current pose: [22.33474105 24.77356211 -1.33888625], tracking point:(23, 23), time:635.9ms
# idx:8, v:1.200, w:0.533, current pose: [22.36232147 24.65677461 -1.28557   ], tracking point:(24, 22), time:627.0ms
# idx:8, v:1.200, w:0.473, current pose: [22.39608643 24.54162285 -1.23825375], tracking point:(24, 22), time:608.1ms
# idx:8, v:1.200, w:0.413, current pose: [22.43526011 24.428197   -1.1969375 ], tracking point:(24, 22), time:627.1ms
# idx:8, v:1.200, w:0.353, current pose: [22.47908536 24.316486   -1.16162125], tracking point:(24, 22), time:569.4ms
# idx:8, v:1.200, w:0.323, current pose: [22.52682768 24.20639208 -1.129305  ], tracking point:(24, 22), time:612.4ms
# idx:8, v:1.200, w:0.263, current pose: [22.57810227 24.09789823 -1.10298875], tracking point:(24, 22), time:595.9ms
# idx:8, v:1.200, w:0.233, current pose: [22.63221393 23.99079114 -1.0796725 ], tracking point:(24, 22), time:566.8ms
# idx:8, v:1.200, w:0.203, current pose: [22.688808   23.88497473 -1.05935625], tracking point:(24, 22), time:608.7ms
# idx:8, v:1.200, w:0.173, current pose: [22.74754002 23.78032986 -1.04204   ], tracking point:(24, 22), time:590.7ms
# idx:8, v:1.200, w:0.173, current pose: [22.80807521 23.67671765 -1.02472375], tracking point:(24, 22), time:594.7ms
# idx:8, v:1.200, w:0.143, current pose: [22.87039541 23.57416916 -1.0104075 ], tracking point:(24, 22), time:597.0ms
# idx:9, v:1.200, w:0.233, current pose: [22.93417728 23.47252334 -0.98709125], tracking point:(25, 21), time:579.7ms
# idx:9, v:1.200, w:0.203, current pose: [23.0003116  23.37239216 -0.966775  ], tracking point:(25, 21), time:580.6ms
# idx:9, v:1.200, w:0.173, current pose: [23.06846642 23.27362516 -0.94945875], tracking point:(25, 21), time:599.1ms
# idx:9, v:1.200, w:0.143, current pose: [23.13832121 23.1760531  -0.9351425 ], tracking point:(25, 21), time:606.1ms
# idx:9, v:1.200, w:0.143, current pose: [23.20956566 23.07949105 -0.92082625], tracking point:(25, 21), time:606.0ms
# idx:9, v:1.200, w:0.113, current pose: [23.28218517 22.98395882 -0.90951   ], tracking point:(25, 21), time:611.6ms
# idx:9, v:1.200, w:0.083, current pose: [23.35588108 22.88925448 -0.90119375], tracking point:(25, 21), time:597.2ms
# idx:9, v:1.200, w:0.083, current pose: [23.43036201 22.79516627 -0.8928775 ], tracking point:(25, 21), time:574.2ms
# idx:9, v:1.200, w:0.083, current pose: [23.50562282 22.70170071 -0.88456125], tracking point:(25, 21), time:593.7ms
# idx:9, v:1.200, w:0.053, current pose: [23.5816583  22.60886426 -0.879245  ], tracking point:(25, 21), time:592.8ms
# idx:9, v:1.200, w:0.053, current pose: [23.65818624 22.51643335 -0.87392875], tracking point:(25, 21), time:618.1ms
# idx:9, v:1.200, w:0.053, current pose: [23.73520449 22.42441058 -0.8686125 ], tracking point:(25, 21), time:608.7ms
# idx:10, v:1.200, w:0.083, current pose: [23.81271086 22.33279856 -0.86029625], tracking point:(26, 20), time:570.0ms
# idx:10, v:1.200, w:0.083, current pose: [23.89097641 22.24183426 -0.85198   ], tracking point:(26, 20), time:598.1ms
# idx:10, v:1.200, w:0.053, current pose: [23.96999573 22.15152398 -0.84666375], tracking point:(26, 20), time:603.5ms
# idx:10, v:1.200, w:0.053, current pose: [24.04949404 22.06163506 -0.8413475 ], tracking point:(26, 20), time:602.2ms
# idx:10, v:1.200, w:0.053, current pose: [24.1294691  21.97217003 -0.83603125], tracking point:(26, 20), time:586.9ms
# idx:10, v:1.200, w:0.053, current pose: [24.20991864 21.88313144 -0.830715  ], tracking point:(26, 20), time:594.3ms
# idx:10, v:1.200, w:0.023, current pose: [24.2908404  21.79452179 -0.82839875], tracking point:(26, 20), time:630.6ms
# idx:10, v:1.200, w:0.023, current pose: [24.37196718 21.70609982 -0.8260825 ], tracking point:(26, 20), time:592.5ms
# idx:10, v:1.200, w:0.023, current pose: [24.45329855 21.61786599 -0.82376625], tracking point:(26, 20), time:607.1ms
# idx:10, v:1.200, w:0.023, current pose: [24.53483407 21.52982079 -0.82145   ], tracking point:(26, 20), time:571.8ms
# idx:10, v:1.200, w:0.023, current pose: [24.61657331 21.44196467 -0.81913375], tracking point:(26, 20), time:597.7ms
# idx:11, v:1.200, w:-0.277, current pose: [24.69851583 21.35429812 -0.8468175 ], tracking point:(26, 19), time:642.1ms
# idx:11, v:1.200, w:-0.397, current pose: [24.77800032 21.26439698 -0.88650125], tracking point:(26, 19), time:602.2ms
# idx:11, v:1.200, w:-0.337, current pose: [24.85385555 21.1714132  -0.920185  ], tracking point:(26, 19), time:591.6ms
# idx:11, v:1.200, w:-0.307, current pose: [24.92653631 21.07592756 -0.95086875], tracking point:(26, 19), time:573.2ms
# idx:11, v:1.200, w:-0.277, current pose: [24.99625345 20.97825709 -0.9785525 ], tracking point:(26, 19), time:602.8ms
# idx:11, v:1.200, w:-0.217, current pose: [25.06324035 20.87869427 -1.00023625], tracking point:(26, 19), time:612.4ms
# idx:11, v:1.200, w:-0.217, current pose: [25.12805277 20.77770243 -1.02192   ], tracking point:(26, 19), time:607.9ms
# idx:12, v:1.200, w:-0.427, current pose: [25.19066024 20.67532908 -1.06460375], tracking point:(26, 18), time:590.8ms
# idx:12, v:1.200, w:-0.397, current pose: [25.24884234 20.57037745 -1.1042875 ], tracking point:(26, 18), time:564.0ms
# idx:12, v:1.200, w:-0.337, current pose: [25.30281485 20.46320018 -1.13797125], tracking point:(26, 18), time:578.6ms
# idx:12, v:1.200, w:-0.277, current pose: [25.35314729 20.35426605 -1.165655  ], tracking point:(26, 18), time:561.2ms
# idx:12, v:1.200, w:-0.247, current pose: [25.40044513 20.24398044 -1.19033875], tracking point:(26, 18), time:563.9ms
# idx:12, v:1.200, w:-0.217, current pose: [25.44500657 20.13256106 -1.2120225 ], tracking point:(26, 18), time:581.1ms
# idx:12, v:1.200, w:-0.187, current pose: [25.48714174 20.02020169 -1.23070625], tracking point:(26, 18), time:591.9ms
# idx:12, v:1.200, w:-0.187, current pose: [25.52717038 19.90707474 -1.24939   ], tracking point:(26, 18), time:564.2ms
# idx:13, v:1.200, w:-0.277, current pose: [25.56507852 19.79321969 -1.27707375], tracking point:(26, 17), time:557.3ms
# idx:13, v:1.200, w:-0.247, current pose: [25.59982061 19.67835896 -1.3017575 ], tracking point:(26, 17), time:572.4ms
# idx:13, v:1.200, w:-0.217, current pose: [25.6317172  19.56267574 -1.32344125], tracking point:(26, 17), time:552.4ms
# idx:13, v:1.200, w:-0.187, current pose: [25.66109805 19.44632813 -1.342125  ], tracking point:(26, 17), time:571.9ms
# idx:13, v:1.200, w:-0.157, current pose: [25.68830009 19.32945192 -1.35780875], tracking point:(26, 17), time:571.5ms
# idx:13, v:1.200, w:-0.157, current pose: [25.7136658  19.21216347 -1.3734925 ], tracking point:(26, 17), time:549.4ms
# idx:13, v:1.200, w:-0.127, current pose: [25.73718894 19.09449163 -1.38617625], tracking point:(26, 17), time:567.8ms
# idx:13, v:1.200, w:-0.127, current pose: [25.75921771 18.9765309  -1.39886   ], tracking point:(26, 17), time:557.4ms
# idx:14, v:1.200, w:-0.157, current pose: [25.77974856 18.85830026 -1.41454375], tracking point:(26, 16), time:551.9ms
# idx:14, v:1.200, w:-0.157, current pose: [25.79842267 18.73976217 -1.4302275 ], tracking point:(26, 16), time:570.8ms
# idx:14, v:1.200, w:-0.127, current pose: [25.81523543 18.6209458  -1.44291125], tracking point:(26, 16), time:583.9ms
# idx:14, v:1.200, w:-0.097, current pose: [25.83053984 18.50192574 -1.452595  ], tracking point:(26, 16), time:556.2ms
# idx:14, v:1.200, w:-0.097, current pose: [25.84469099 18.38276306 -1.46227875], tracking point:(26, 16), time:553.2ms
# idx:14, v:1.200, w:-0.067, current pose: [25.85768756 18.26346893 -1.4689625 ], tracking point:(26, 16), time:576.7ms
# idx:14, v:1.200, w:-0.067, current pose: [25.86988651 18.1440906  -1.47564625], tracking point:(26, 16), time:600.5ms
# idx:14, v:1.200, w:-0.067, current pose: [25.8812873 18.0246334 -1.48233  ], tracking point:(26, 16), time:549.5ms
# idx:14, v:1.200, w:-0.067, current pose: [25.89188942 17.90510267 -1.48901375], tracking point:(26, 16), time:545.7ms
# idx:15, v:1.200, w:-0.067, current pose: [25.90169239 17.78550375 -1.4956975 ], tracking point:(26, 15), time:572.6ms
# idx:15, v:1.200, w:-0.067, current pose: [25.91069578 17.66584198 -1.50238125], tracking point:(26, 15), time:561.9ms
# idx:15, v:1.200, w:-0.067, current pose: [25.91889918 17.54612271 -1.509065  ], tracking point:(26, 15), time:555.1ms
# idx:15, v:1.200, w:-0.067, current pose: [25.92630224 17.42635128 -1.51574875], tracking point:(26, 15), time:538.8ms
# idx:15, v:1.200, w:-0.037, current pose: [25.93290461 17.30653305 -1.5194325 ], tracking point:(26, 15), time:544.2ms
# idx:15, v:1.200, w:-0.037, current pose: [25.93906556 17.18669131 -1.52311625], tracking point:(26, 15), time:555.8ms
# idx:15, v:1.200, w:-0.037, current pose: [25.944785   17.06682769 -1.5268    ], tracking point:(26, 15), time:593.5ms
# idx:15, v:1.200, w:-0.037, current pose: [25.95006286 16.94694381 -1.53048375], tracking point:(26, 15), time:569.3ms
# idx:16, v:1.200, w:-0.037, current pose: [25.95489906 16.8270413  -1.5341675 ], tracking point:(26, 14), time:544.6ms
# idx:16, v:1.200, w:-0.037, current pose: [25.95929354 16.70712179 -1.53785125], tracking point:(26, 14), time:537.4ms
# idx:16, v:1.200, w:-0.037, current pose: [25.96324623 16.58718691 -1.541535  ], tracking point:(26, 14), time:551.2ms
# idx:16, v:1.200, w:-0.037, current pose: [25.96675709 16.46723828 -1.54521875], tracking point:(26, 14), time:557.2ms
# idx:16, v:1.200, w:-0.037, current pose: [25.96982606 16.34727753 -1.5489025 ], tracking point:(26, 14), time:563.0ms
# idx:16, v:1.200, w:-0.007, current pose: [25.97245311 16.22730629 -1.54958625], tracking point:(26, 14), time:558.3ms
# idx:16, v:1.200, w:-0.007, current pose: [25.97499813 16.10733328 -1.55027   ], tracking point:(26, 14), time:536.7ms
# idx:16, v:1.200, w:-0.007, current pose: [25.97746112 15.98735856 -1.55095375], tracking point:(26, 14), time:570.5ms
# idx:17, v:1.200, w:-0.007, current pose: [25.97984207 15.86738218 -1.5516375 ], tracking point:(26, 14), time:548.2ms
# idx:18, v:1.200, w:-0.007, current pose: [25.98214099 15.74740421 -1.55232125], tracking point:(26, 14), time:582.6ms
# idx:19, v:1.200, w:-0.007, current pose: [25.98435787 15.62742468 -1.553005  ], tracking point:(26, 14), time:550.7ms
# idx:20, v:1.200, w:-0.007, current pose: [25.98649272 15.50744368 -1.55368875], tracking point:(26, 14), time:565.3ms
# idx:21, v:1.200, w:-0.007, current pose: [25.98854553 15.38746124 -1.5543725 ], tracking point:(26, 14), time:592.0ms
# idx:22, v:1.200, w:-0.007, current pose: [25.9905163  15.26747742 -1.55505625], tracking point:(26, 14), time:574.9ms
# idx:23, v:1.200, w:-0.007, current pose: [25.99240503 15.14749228 -1.55574   ], tracking point:(26, 14), time:556.2ms
# idx:24, v:1.150, w:-0.007, current pose: [25.99413644 15.03250532 -1.55642375], tracking point:(26, 14), time:572.3ms
# idx:25, v:1.100, w:-0.007, current pose: [25.99571737 14.92251668 -1.5571075 ], tracking point:(26, 14), time:586.8ms

# %%
plot_final_path(grid_modified_dense,astar_path,logs,extent_limits)
# Out:
# /content/collision_dwa.py:131: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   poses = np.array(logs)[:,:3]

# %%
plot_wvk(logs)
# Out:
# /content/collision_dwa.py:143: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   v = np.array(logs)[:,3]
# /content/collision_dwa.py:144: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   w = np.array(logs)[:,4]
