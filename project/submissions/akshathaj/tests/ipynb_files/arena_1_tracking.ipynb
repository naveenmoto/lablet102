# %%
import time
import toml
import numpy as np
import matplotlib.pyplot as plt
from ref_trajectory import plot_smooth_route
from ref_trajectory import generate_trajectory as traj
from astar import gen_astar_path, plot_astar
from route_directions import make_route,euclidean
from collision_dwa import simulate_unicycle,track,plot_final_path,plot_wvk
from environment_setup import grid_from_map,place_obstacles,plot_environment,densify_grid
# %matplotlib inline

config_params = toml.load("config.toml")['params']
locals().update(config_params)

# %%
data = np.loadtxt("arena_1.map", skiprows=4, dtype='str')
data_header = np.loadtxt("arena_1.map", skiprows=1, max_rows = 2, dtype = 'str')
data_size = [int(data_header[0][1]), int(data_header[1][1])]
grid = grid_from_map(data,data_size)
start = (4, 37)
goal = (36, 16)
astar_path,extent_limits = gen_astar_path(grid,start,goal)
plot_astar(grid,start,goal,astar_path,extent_limits)

# %%
grid_dense = densify_grid(grid)
plot_astar(grid_dense,start,goal,astar_path,extent_limits)

# %%
pose = (*astar_path[0],0)
logs = []
path_index = 0
v, w = 0.0, 0.0
while path_index < len(astar_path)-1:
    t0 = time.time()
    local_ref_path = astar_path[path_index:path_index+pred_horizon]
    # update path_index using current pose and local_ref_path
    if euclidean(pose[:2],local_ref_path[-1][:2]) < goal_threshold*4*pred_horizon:
        path_index = path_index + 1
        local_ref_path = astar_path[path_index:path_index+pred_horizon]
    # get next command
    v, w = track(grid_dense,local_ref_path,pose,v,w)
    
    #simulate vehicle for 1 step
    # remember the function now returns a trajectory, not a single pose
    pose = simulate_unicycle(pose,v,w)[-1]
    
    #update logs
    logs.append([*pose, v, w, local_ref_path[-1]])
    t1 = time.time() #simplest way to time-profile your code
    print(f"idx:{path_index}, v:{v:0.3f}, w:{w:0.3f}, current pose: {pose}, tracking point:{local_ref_path[-1][:2]}, time:{(t1-t0) * 1000:0.1f}ms")
# Out:
# Streaming output truncated to the last 5000 lines.
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# local path has a collision, best_command = (1.165, 0.04020000000000534), cost = 1.2607980628483884
# idx:19, v:1.165, w:0.040, current pose: [29.87901229 17.13933155  0.51042   ], tracking point:(32, 18), time:598.6ms
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# local path has a collision, best_command = (1.183, 0.3402000000000054), cost = 1.2013838990167303
# idx:19, v:1.183, w:0.340, current pose: [29.9822337  17.19712628  0.54444   ], tracking point:(32, 18), time:602.2ms
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# local path has a collision, best_command = (1.2, 0.4302000000000054), cost = 1.1367749118121675
# idx:19, v:1.200, w:0.430, current pose: [30.0848838  17.25927898  0.58746   ], tracking point:(32, 18), time:539.4ms
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# local path has a collision, best_command = (1.2, 0.46020000000000544), cost = 1.087100409306986
# ...
# local path has a collision, best_command = (1.2, -0.03726249999999953), cost = 1.9939177434225828
# local path has a collision, best_command = (1.2, -0.03726249999999953), cost = 1.9939177434225828
# local path has a collision, best_command = (1.2, -0.03726249999999953), cost = 1.9939177434225828
# local path has a collision, best_command = (1.2, -0.03726249999999953), cost = 1.9939177434225828
# local path has a collision, best_command = (1.2, -0.03726249999999953), cost = 1.9939177434225828
# local path has a collision, best_command = (1.2, -0.03726249999999953), cost = 1.9939177434225828
# local path has a collision, best_command = (1.2, -0.06726249999999956), cost = 1.9777215916980146
# local path has a collision, best_command = (1.2, -0.06726249999999956), cost = 1.9777215916980146
# local path has a collision, best_command = (1.2, -0.06726249999999956), cost = 1.9777215916980146
# local path has a collision, best_command = (1.2, -0.06726249999999956), cost = 1.9777215916980146
# local path has a collision, best_command = (1.2, -0.06726249999999956), cost = 1.9777215916980146
# local path has a collision, best_command = (1.2, -0.06726249999999956), cost = 1.9777215916980146
# local path has a collision, best_command = (1.2, -0.06726249999999956), cost = 1.9777215916980146
# local path has a collision, best_command = (1.2, -0.06726249999999956), cost = 1.9777215916980146
# local path has a collision, best_command = (1.2, -0.09726249999999953), cost = 1.9615354920425594
# local path has a collision, best_command = (1.2, -0.09726249999999953), cost = 1.9615354920425594
# local path has a collision, best_command = (1.2, -0.09726249999999953), cost = 1.9615354920425594
# local path has a collision, best_command = (1.2, -0.09726249999999953), cost = 1.9615354920425594
# local path has a collision, best_command = (1.2, -0.09726249999999953), cost = 1.9615354920425594
# local path has a collision, best_command = (1.2, -0.09726249999999953), cost = 1.9615354920425594
# local path has a collision, best_command = (1.2, -0.09726249999999953), cost = 1.9615354920425594
# local path has a collision, best_command = (1.2, -0.09726249999999953), cost = 1.9615354920425594
# local path has a collision, best_command = (1.2, -0.12726249999999956), cost = 1.9453662811044208
# local path has a collision, best_command = (1.2, -0.12726249999999956), cost = 1.9453662811044208
# local path has a collision, best_command = (1.2, -0.12726249999999956), cost = 1.9453662811044208
# local path has a collision, best_command = (1.2, -0.12726249999999956), cost = 1.9453662811044208
# local path has a collision, best_command = (1.2, -0.12726249999999956), cost = 1.9453662811044208
# local path has a collision, best_command = (1.2, -0.12726249999999956), cost = 1.9453662811044208
# local path has a collision, best_command = (1.2, -0.12726249999999956), cost = 1.9453662811044208
# local path has a collision, best_command = (1.2, -0.12726249999999956), cost = 1.9453662811044208
# local path has a collision, best_command = (1.2, -0.15726249999999953), cost = 1.9292209420770812
# local path has a collision, best_command = (1.2, -0.15726249999999953), cost = 1.9292209420770812
# local path has a collision, best_command = (1.2, -0.15726249999999953), cost = 1.9292209420770812
# local path has a collision, best_command = (1.2, -0.15726249999999953), cost = 1.9292209420770812
# local path has a collision, best_command = (1.2, -0.15726249999999953), cost = 1.9292209420770812
# local path has a collision, best_command = (1.2, -0.15726249999999953), cost = 1.9292209420770812
# local path has a collision, best_command = (1.2, -0.15726249999999953), cost = 1.9292209420770812
# local path has a collision, best_command = (1.2, -0.15726249999999953), cost = 1.9292209420770812
# local path has a collision, best_command = (1.2, -0.18726249999999955), cost = 1.913106606613414
# local path has a collision, best_command = (1.2, -0.18726249999999955), cost = 1.913106606613414
# local path has a collision, best_command = (1.2, -0.18726249999999955), cost = 1.913106606613414
# local path has a collision, best_command = (1.2, -0.18726249999999955), cost = 1.913106606613414
# local path has a collision, best_command = (1.2, -0.18726249999999955), cost = 1.913106606613414
# local path has a collision, best_command = (1.2, -0.18726249999999955), cost = 1.913106606613414
# local path has a collision, best_command = (1.2, -0.18726249999999955), cost = 1.913106606613414
# local path has a collision, best_command = (1.2, -0.18726249999999955), cost = 1.913106606613414
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8970305565993755
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8970305565993755
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8970305565993755
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8970305565993755
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8970305565993755
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8970305565993755
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8970305565993755
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8970305565993755
# local path has a collision, best_command = (1.2, -0.24726249999999955), cost = 1.8810002257607843
# local path has a collision, best_command = (1.2, -0.24726249999999955), cost = 1.8810002257607843
# local path has a collision, best_command = (1.2, -0.24726249999999955), cost = 1.8810002257607843
# local path has a collision, best_command = (1.2, -0.24726249999999955), cost = 1.8810002257607843
# local path has a collision, best_command = (1.2, -0.24726249999999955), cost = 1.8810002257607843
# local path has a collision, best_command = (1.2, -0.24726249999999955), cost = 1.8810002257607843
# local path has a collision, best_command = (1.2, -0.24726249999999955), cost = 1.8810002257607843
# local path has a collision, best_command = (1.2, -0.2772624999999996), cost = 1.865023201073727
# local path has a collision, best_command = (1.2, -0.2772624999999996), cost = 1.865023201073727
# local path has a collision, best_command = (1.2, -0.2772624999999996), cost = 1.865023201073727
# local path has a collision, best_command = (1.2, -0.2772624999999996), cost = 1.865023201073727
# local path has a collision, best_command = (1.2, -0.2772624999999996), cost = 1.865023201073727
# local path has a collision, best_command = (1.2, -0.2772624999999996), cost = 1.865023201073727
# local path has a collision, best_command = (1.2, -0.2772624999999996), cost = 1.865023201073727
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.849107223946854
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.849107223946854
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.849107223946854
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.849107223946854
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.849107223946854
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.849107223946854
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.849107223946854
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.8332601911404367
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.8332601911404367
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.8332601911404367
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.8332601911404367
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.8332601911404367
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.8332601911404367
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.8332601911404367
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.81749015538459
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.81749015538459
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.81749015538459
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.81749015538459
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.81749015538459
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.81749015538459
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.81749015538459
# local path has a collision, best_command = (1.2, -0.39726249999999963), cost = 1.8018053256555968
# local path has a collision, best_command = (1.2, -0.39726249999999963), cost = 1.8018053256555968
# local path has a collision, best_command = (1.2, -0.39726249999999963), cost = 1.8018053256555968
# local path has a collision, best_command = (1.2, -0.39726249999999963), cost = 1.8018053256555968
# local path has a collision, best_command = (1.2, -0.39726249999999963), cost = 1.8018053256555968
# local path has a collision, best_command = (1.2, -0.39726249999999963), cost = 1.8018053256555968
# local path has a collision, best_command = (1.2, -0.39726249999999963), cost = 1.8018053256555968
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7862140670663122
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7862140670663122
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7862140670663122
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7862140670663122
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7862140670663122
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7862140670663122
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7862140670663122
# local path has a collision, best_command = (1.2, -0.4572624999999996), cost = 1.770724900323298
# local path has a collision, best_command = (1.2, -0.4572624999999996), cost = 1.770724900323298
# local path has a collision, best_command = (1.2, -0.4572624999999996), cost = 1.770724900323298
# local path has a collision, best_command = (1.2, -0.4572624999999996), cost = 1.770724900323298
# local path has a collision, best_command = (1.2, -0.4572624999999996), cost = 1.770724900323298
# local path has a collision, best_command = (1.2, -0.4572624999999996), cost = 1.770724900323298
# local path has a collision, best_command = (1.2, -0.4572624999999996), cost = 1.770724900323298
# local path has a collision, best_command = (1.2, -0.4872624999999996), cost = 1.7553465007001627
# local path has a collision, best_command = (1.2, -0.4872624999999996), cost = 1.7553465007001627
# idx:23, v:1.200, w:-0.517, current pose: [35.11591516 18.09125307 -0.13184   ], tracking point:(36, 16), time:345.0ms
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8404254800755273
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8404254800755273
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8404254800755273
# local path has a collision, best_command = (1.2, -0.21726249999999958), cost = 1.8404254800755273
# local path has a collision, best_command = (1.2, -0.2472624999999996), cost = 1.8243745285324837
# local path has a collision, best_command = (1.2, -0.2472624999999996), cost = 1.8243745285324837
# local path has a collision, best_command = (1.2, -0.2472624999999996), cost = 1.8243745285324837
# local path has a collision, best_command = (1.2, -0.2472624999999996), cost = 1.8243745285324837
# local path has a collision, best_command = (1.2, -0.2772624999999995), cost = 1.8083736023600783
# local path has a collision, best_command = (1.2, -0.2772624999999995), cost = 1.8083736023600783
# local path has a collision, best_command = (1.2, -0.2772624999999995), cost = 1.8083736023600783
# local path has a collision, best_command = (1.2, -0.2772624999999995), cost = 1.8083736023600783
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.7924304104508788
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.7924304104508788
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.7924304104508788
# local path has a collision, best_command = (1.2, -0.30726249999999955), cost = 1.7924304104508788
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.7765528243973168
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.7765528243973168
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.7765528243973168
# local path has a collision, best_command = (1.2, -0.3372624999999996), cost = 1.7765528243973168
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.7607488797348985
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.7607488797348985
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.7607488797348985
# local path has a collision, best_command = (1.2, -0.3672624999999996), cost = 1.7607488797348985
# local path has a collision, best_command = (1.2, -0.3972624999999996), cost = 1.7450267768669023
# local path has a collision, best_command = (1.2, -0.3972624999999996), cost = 1.7450267768669023
# local path has a collision, best_command = (1.2, -0.3972624999999996), cost = 1.7450267768669023
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7293948816249023
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7293948816249023
# local path has a collision, best_command = (1.2, -0.4272624999999996), cost = 1.7293948816249023
# local path has a collision, best_command = (1.2, -0.45726249999999957), cost = 1.7138617254151194
# local path has a collision, best_command = (1.2, -0.45726249999999957), cost = 1.7138617254151194
# local path has a collision, best_command = (1.2, -0.45726249999999957), cost = 1.7138617254151194
# local path has a collision, best_command = (1.2, -0.4872624999999996), cost = 1.6984360048972333
# idx:23, v:1.200, w:-0.817, current pose: [35.23487376 18.07547806 -0.21356625], tracking point:(36, 16), time:461.7ms
# idx:23, v:1.200, w:-1.000, current pose: [35.35214751 18.05004449 -0.31356625], tracking point:(36, 16), time:485.0ms
# idx:23, v:1.200, w:-1.000, current pose: [35.46629627 18.01303013 -0.41356625], tracking point:(36, 16), time:486.7ms
# idx:23, v:1.200, w:-1.000, current pose: [35.57617948 17.96480484 -0.51356625], tracking point:(36, 16), time:486.8ms
# idx:23, v:1.200, w:-1.000, current pose: [35.68069924 17.90585045 -0.61356625], tracking point:(36, 16), time:480.7ms
# idx:24, v:1.200, w:-1.000, current pose: [35.77881122 17.83675602 -0.71356625], tracking point:(36, 16), time:479.2ms
# idx:25, v:1.200, w:-1.000, current pose: [35.86953511 17.75821193 -0.81356625], tracking point:(36, 16), time:489.5ms
# idx:26, v:1.200, w:-1.000, current pose: [35.95196444 17.67100295 -0.91356625], tracking point:(36, 16), time:480.6ms
# idx:27, v:1.200, w:-1.000, current pose: [36.0252756  17.57600045 -1.01356625], tracking point:(36, 16), time:470.1ms
# idx:28, v:1.200, w:-1.000, current pose: [36.08873608 17.47415367 -1.11356625], tracking point:(36, 16), time:472.0ms
# idx:29, v:1.200, w:-1.000, current pose: [36.14171181 17.36648022 -1.21356625], tracking point:(36, 16), time:459.0ms
# idx:30, v:1.200, w:-0.955, current pose: [36.18367347 17.25405594 -1.30906625], tracking point:(36, 16), time:468.9ms
# idx:31, v:1.200, w:-0.879, current pose: [36.21472372 17.13814268 -1.39699125], tracking point:(36, 16), time:462.2ms
# idx:32, v:1.190, w:-0.811, current pose: [36.23530255 17.02093555 -1.4780575 ], tracking point:(36, 16), time:474.5ms

# %%
plot_final_path(grid_modified_dense,astar_path,logs,extent_limits)
# Out:
# /content/collision_dwa.py:131: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   poses = np.array(logs)[:,:3]

# %%
plot_wvk(logs)
# Out:
# /content/collision_dwa.py:143: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   v = np.array(logs)[:,3]
# /content/collision_dwa.py:144: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   w = np.array(logs)[:,4]
