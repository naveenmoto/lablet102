# %%
import time
import toml
import numpy as np
import matplotlib.pyplot as plt
from ref_trajectory import plot_smooth_route
from ref_trajectory import generate_trajectory as traj
from astar_4_path import gen_astar_path, plot_astar
from route_directions import make_route,euclidean
from collision_dwa import simulate_unicycle,track,plot_final_path,plot_wvk
from environment_setup import grid_from_map,place_obstacles,plot_environment,densify_grid
# %matplotlib inline

config_params = toml.load("config.toml")['params']
locals().update(config_params)

# %%
grid = np.load("astar_grid.npy")
start = (0,19)
goal = (19,19)
astar_path,extent_limits = gen_astar_path(grid,start,goal)
plot_astar(grid,start,goal,astar_path,extent_limits)

# %%
grid_dense = densify_grid(grid)
plot_astar(grid_dense,start,goal,astar_path,extent_limits)

# %%
route,corners,r = make_route(astar_path)
if astar_path[0][0] > astar_path[1][0]:
  t0 = np.pi
elif astar_path[0][0] < astar_path[1][0]:
  t0 = 0
elif astar_path[0][1] < astar_path[1][1]:
  t0 = np.pi/2
elif astar_path[0][1] < astar_path[1][1]:
  t0 = -np.pi/2

start_pose = (*start,t0)
ref_path = traj(route,r,start_pose).T
rx,ry,t = ref_path.T
plot_smooth_route(grid_dense,start,goal,astar_path,rx,ry,extent_limits)

# %%
pose = (*astar_path[0],0)
logs = []
path_index = 0
v, w = 0.0, 0.0
while path_index < len(astar_path)-1:
    t0 = time.time()
    local_ref_path = astar_path[path_index:path_index+pred_horizon]
    # update path_index using current pose and local_ref_path
    if euclidean(pose[:2],local_ref_path[-1][:2]) < goal_threshold*4*pred_horizon:
        path_index = path_index + 1
        local_ref_path = astar_path[path_index:path_index+pred_horizon]
    # get next command
    v, w = track(grid_dense,local_ref_path,pose,v,w)
    
    #simulate vehicle for 1 step
    # remember the function now returns a trajectory, not a single pose
    pose = simulate_unicycle(pose,v,w)[-1]
    
    #update logs
    logs.append([*pose, v, w, local_ref_path[-1]])
    t1 = time.time() #simplest way to time-profile your code
    print(f"idx:{path_index}, v:{v:0.3f}, w:{w:0.3f}, current pose: {pose}, tracking point:{local_ref_path[-1][:2]}, time:{(t1-t0) * 1000:0.1f}ms")
# Out:
# Streaming output truncated to the last 5000 lines.
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = (0.16000000000000003, -0.08999999999999991), cost = 3.2034519972960815
# local path has a collision, best_command = (0.25, -0.11999999999999994), cost = 3.0056840705153625
# local path has a collision, best_command = (0.25, -0.11999999999999994), cost = 3.0056840705153625
# local path has a collision, best_command = (0.25, -0.11999999999999994), cost = 3.0056840705153625
# idx:38, v:0.250, w:-0.120, current pose: [14.15694753  5.87662909  1.86992951], tracking point:(12, 6), time:346.1ms
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = (0.26, -0.11999999999999994), cost = 2.9814386930606247
# local path has a collision, best_command = (0.26, -0.11999999999999994), cost = 2.9814386930606247
# local path has a collision, best_command = (0.26, -0.11999999999999994), cost = 2.9814386930606247
# local path has a collision, best_command = (0.26, -0.11999999999999994), cost = 2.9814386930606247
# local path has a collision, best_command = (0.26, -0.11999999999999994), cost = 2.9814386930606247
# local path has a collision, best_command = (0.26, -0.11999999999999994), cost = 2.9814386930606247
# local path has a collision, best_command = (0.27, -0.1499999999999999), cost = 2.964539498904813
# local path has a collision, best_command = (0.27, -0.1499999999999999), cost = 2.964539498904813
# idx:38, v:0.300, w:-0.210, current pose: [14.14810677  5.90529686  1.84892951], tracking point:(12, 6), time:355.0ms
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = (0.27, -0.11999999999999994), cost = 2.9598102248517257
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# local path has a collision, best_command = (0.33999999999999997, -0.1499999999999999), cost = 2.830216988640004
# idx:38, v:0.340, w:-0.150, current pose: [14.13877169  5.93799022  1.83392951], tracking point:(12, 6), time:363.9ms
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = None, cost = inf
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.35, 0.09000000000000019), cost = 2.77474783530929
# local path has a collision, best_command = (0.37999999999999995, -0.05999999999999989), cost = 2.745205051638797
# local path has a collision, best_command = (0.37999999999999995, -0.05999999999999989), cost = 2.745205051638797
# local path has a collision, best_command = (0.37999999999999995, -0.05999999999999989), cost = 2.745205051638797
# local path has a collision, best_command = (0.37999999999999995, -0.05999999999999989), cost = 2.745205051638797
# local path has a collision, best_command = (0.37999999999999995, -0.05999999999999989), cost = 2.745205051638797
# local path has a collision, best_command = (0.37999999999999995, -0.05999999999999989), cost = 2.745205051638797
# local path has a collision, best_command = (0.37999999999999995, -0.05999999999999989), cost = 2.745205051638797
# local path has a collision, best_command = (0.37999999999999995, -0.05999999999999989), cost = 2.745205051638797
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# local path has a collision, best_command = (0.38999999999999996, -0.08999999999999986), cost = 2.7333114614344662
# idx:38, v:0.390, w:-0.090, current pose: [14.12862752  5.97564784  1.82492951], tracking point:(12, 6), time:356.9ms
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# local path has a collision, best_command = (0.43999999999999995, 0.2100000000000002), cost = 2.5939571957695726
# ...
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# local path has a collision, best_command = (1.2, 0.39479940625000043), cost = 1.3676213214630226
# idx:57, v:1.200, w:0.395, current pose: [18.10950366 12.94044658  0.81958375], tracking point:(18, 15), time:332.1ms
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# local path has a collision, best_command = (1.2, 0.6947994062500005), cost = 1.1662403287502672
# idx:57, v:1.200, w:0.695, current pose: [18.19140672 13.02815     0.88906369], tracking point:(18, 15), time:470.0ms
# idx:58, v:1.200, w:0.995, current pose: [18.26702344 13.12132785  0.98854363], tracking point:(18, 16), time:478.5ms
# idx:58, v:1.200, w:1.000, current pose: [18.33301226 13.22155497  1.08854363], tracking point:(18, 16), time:478.1ms
# idx:58, v:1.200, w:1.000, current pose: [18.3886654  13.32786926  1.18854363], tracking point:(18, 16), time:458.8ms
# idx:58, v:1.200, w:0.955, current pose: [18.43342678 13.43920846  1.28404363], tracking point:(18, 16), time:459.9ms
# idx:58, v:1.200, w:0.828, current pose: [18.46736746 13.55430855  1.36679363], tracking point:(18, 16), time:454.6ms
# idx:58, v:1.200, w:0.716, current pose: [18.49167834 13.67182017  1.43844363], tracking point:(18, 16), time:457.4ms
# idx:58, v:1.200, w:0.621, current pose: [18.50751433 13.79077067  1.50051613], tracking point:(18, 16), time:472.2ms
# idx:58, v:1.200, w:0.561, current pose: [18.51594102 13.91047443  1.55658863], tracking point:(18, 16), time:461.1ms
# idx:58, v:1.200, w:0.471, current pose: [18.51764588 14.03046232  1.60366113], tracking point:(18, 16), time:470.6ms
# idx:58, v:1.200, w:0.441, current pose: [18.51370281 14.15039752  1.64773363], tracking point:(18, 16), time:487.5ms
# idx:59, v:1.200, w:0.171, current pose: [18.50447944 14.27004254  1.66480613], tracking point:(18, 17), time:468.3ms
# idx:59, v:1.200, w:0.171, current pose: [18.49321488 14.38951266  1.68187863], tracking point:(18, 17), time:451.3ms
# idx:59, v:1.200, w:0.141, current pose: [18.4799124  14.50877306  1.69595113], tracking point:(18, 17), time:463.6ms
# idx:59, v:1.200, w:0.111, current pose: [18.464933   14.62783446  1.70702363], tracking point:(18, 17), time:463.9ms
# idx:59, v:1.200, w:0.111, current pose: [18.44863624 14.74672271  1.71809613], tracking point:(18, 17), time:465.2ms
# idx:59, v:1.200, w:0.081, current pose: [18.43102411 14.86542323  1.72616863], tracking point:(18, 17), time:459.7ms
# idx:59, v:1.200, w:0.081, current pose: [18.41245436 14.98397771  1.73424113], tracking point:(18, 17), time:464.9ms
# idx:59, v:1.200, w:0.081, current pose: [18.39292819 15.10237842  1.74231363], tracking point:(18, 17), time:464.6ms
# idx:60, v:1.200, w:-0.069, current pose: [18.37244688 15.22061765  1.73538613], tracking point:(18, 18), time:457.9ms
# idx:60, v:1.200, w:-0.069, current pose: [18.35278516 15.33899593  1.72845863], tracking point:(18, 18), time:442.1ms
# idx:60, v:1.200, w:-0.039, current pose: [18.33394396 15.45750757  1.72453113], tracking point:(18, 18), time:442.1ms
# idx:60, v:1.200, w:-0.039, current pose: [18.31556837 15.5760923   1.72060363], tracking point:(18, 18), time:473.8ms
# idx:60, v:1.200, w:-0.039, current pose: [18.29765866 15.69474828  1.71667613], tracking point:(18, 18), time:460.7ms
# idx:60, v:1.200, w:-0.039, current pose: [18.2802151  15.81347369  1.71274863], tracking point:(18, 18), time:473.9ms
# idx:60, v:1.200, w:-0.039, current pose: [18.26323798 15.93226669  1.70882113], tracking point:(18, 18), time:455.9ms
# idx:60, v:1.200, w:-0.009, current pose: [18.24672754 16.05112546  1.70789363], tracking point:(18, 18), time:459.2ms
# idx:61, v:1.200, w:-0.099, current pose: [18.23032735 16.16999948  1.69796613], tracking point:(18, 19), time:452.7ms
# idx:61, v:1.200, w:-0.069, current pose: [18.21510808 16.28903046  1.69103863], tracking point:(18, 19), time:466.7ms
# idx:61, v:1.200, w:-0.069, current pose: [18.20071374 16.40816401  1.68411113], tracking point:(18, 19), time:458.5ms
# idx:61, v:1.200, w:-0.069, current pose: [18.18714505 16.52739442  1.67718363], tracking point:(18, 19), time:473.6ms
# idx:61, v:1.200, w:-0.069, current pose: [18.17440264 16.64671596  1.67025613], tracking point:(18, 19), time:450.7ms
# idx:61, v:1.200, w:-0.039, current pose: [18.16248713 16.76612292  1.66632863], tracking point:(18, 19), time:450.8ms
# idx:61, v:1.200, w:-0.039, current pose: [18.15104068 16.88557575  1.66240113], tracking point:(18, 19), time:462.7ms
# idx:61, v:1.200, w:-0.039, current pose: [18.14006347 17.00507261  1.65847363], tracking point:(18, 19), time:452.8ms
# idx:62, v:1.200, w:-0.339, current pose: [18.12955567 17.12461167  1.62454613], tracking point:(19, 19), time:450.1ms
# idx:62, v:1.200, w:-0.639, current pose: [18.1231088  17.24443837  1.56061863], tracking point:(19, 19), time:464.9ms
# idx:63, v:1.200, w:-0.849, current pose: [18.1243301  17.36443216  1.47569113], tracking point:(19, 19), time:466.0ms
# idx:64, v:1.200, w:-0.775, current pose: [18.13572553 17.48388986  1.39822738], tracking point:(19, 19), time:484.2ms
# idx:65, v:1.200, w:-0.685, current pose: [18.15633117 17.60210749  1.32974913], tracking point:(19, 19), time:473.6ms
# idx:66, v:1.200, w:-0.595, current pose: [18.18497754 17.71863811  1.27027088], tracking point:(19, 19), time:486.6ms
# idx:67, v:1.200, w:-0.535, current pose: [18.22050019 17.83325984  1.21679263], tracking point:(19, 19), time:488.6ms
# idx:68, v:1.200, w:-0.505, current pose: [18.26209891 17.94581892  1.16631438], tracking point:(19, 19), time:472.9ms
# idx:69, v:1.200, w:-0.445, current pose: [18.30932402 18.05613569  1.12183613], tracking point:(19, 19), time:488.0ms
# idx:70, v:1.180, w:-0.415, current pose: [18.36053944 18.16244176  1.08035788], tracking point:(19, 19), time:489.7ms
# idx:71, v:1.130, w:-0.355, current pose: [18.41376388 18.26212205  1.04487963], tracking point:(19, 19), time:476.2ms

# %%
plot_final_path(grid_dense,ref_path,logs,extent_limits)
# Out:
# /content/collision_dwa.py:131: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   poses = np.array(logs)[:,:3]

# %%
plot_wvk(logs)
# Out:
# /content/collision_dwa.py:143: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   v = np.array(logs)[:,3]
# /content/collision_dwa.py:144: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   w = np.array(logs)[:,4]
